# %% [markdown]
# # 03 QSAR Regression Baseline\n\n**Objective:** Build a simple regression baseline using molecular descriptors and an example continuous target.\n\nThis is a starter placeholder notebook. Replace or expand it with your real project work later.\n

# %% [markdown]
# ## Notes\n\n- Keep the notebook reproducible.\n- Use relative paths such as `../data/example_molecules.csv`.\n- Avoid committing private datasets, credentials or large files.\n

# %%
from pathlib import Path
import sys
import pandas as pd

sys.path.append("../src")
from chem_ml_utils import build_descriptor_table, get_numeric_feature_columns

df = pd.read_csv(Path("../data/example_molecules.csv"))
descriptor_df = build_descriptor_table(df)

target_column = "example_target_logS"
feature_columns = get_numeric_feature_columns(descriptor_df, exclude=[target_column])

print("Feature columns:", feature_columns)
descriptor_df[feature_columns + [target_column]].head()

# %% [markdown]
# ## Next steps\n\n- Add real analysis cells.\n- Add plots or molecule images if useful.\n- Add a short conclusion at the end.\n
